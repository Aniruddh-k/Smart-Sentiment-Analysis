# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/test.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                               text  label  \
# 0           0  central theme movie seems confusion relationsh...      0
# 1           1  excellent example cowboy noir called unemploye...      1
# 2           2  ending made heart jump throat proceeded leave ...      0
# 3           3  chosen one appreciate quality story character ...      1
# 4           4  really funny film especially second third four...      1
#
#    Pred_label
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1

# %%
false_positive = df[(df['label'] == 0) & (df['Pred_label'] == 1)]

# %%
false_negative = df[(df['label'] == 1) & (df['Pred_label'] == 0)]

# %%
false_positive.head()
# Out:
#     Unnamed: 0                                               text  label  \
# 2            2  ending made heart jump throat proceeded leave ...      0
# 26          26  give show six fact show fact platform damon wa...      0
# 41          41  jack higgins straightforward thriller guiltrid...      0
# 53          53  agree everyones opinion show poorly produced w...      0
# 56          56  ive seen movie time truly get funnier every ti...      0
#
#     Pred_label
# 2            1
# 26           1
# 41           1
# 53           1
# 56           1

# %%
false_positive['text'][2]
# Out:
# 'ending made heart jump throat proceeded leave movie theater little jittery nearly midnight movie better expected dont know didnt last long theater make much money anticipated definitely would recommend'

# %%
false_negative.head()
# Out:
#     Unnamed: 0                                               text  label  \
# 10          10  nothing new tired seriocomedy waste talent dan...      1
# 35          35  im giving film arent enough specific scientifi...      1
# 37          37  ok plot point might bit obvious interesting id...      1
# 78          78  first movie joan crawford clark gable made tog...      1
# 93          93  zombie bloodbath movie made zombie fan zombie ...      1
#
#     Pred_label
# 10           0
# 35           0
# 37           0
# 78           0
# 93           0

# %%
false_negative['text'][10]
# Out:
# 'nothing new tired seriocomedy waste talent danny glover whoopi goldberg considering produced star spike lee pretty tame tired stuff come whoop never change hair glass many year film cover blah'
