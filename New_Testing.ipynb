# %%
import pandas as pd
import re
import joblib

# %%
df = pd.read_csv(r'/content/Reviews.csv')

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
df_clean = df.drop(['Id', 'ProductId','ProfileName', 'HelpfulnessNumerator',
       'HelpfulnessDenominator', 'Score', 'Time', 'Summary'],axis = 1)

# %%
df_clean.head()
# Out:
#            UserId                                               Text
# 0  A3SGXH7AUHU8GW  I have bought several of the Vitality canned d...
# 1  A1D87F6ZCVE5NK  Product arrived labeled as Jumbo Salted Peanut...
# 2   ABXLMWJIXXAIN  This is a confection that has been around a fe...
# 3  A395BORC6FGVXV  If you are looking for the secret ingredient i...
# 4  A1UQRSCLF8GW1T  Great taffy at a great price.  There was a wid...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8187 entries, 0 to 8186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   UserId  8187 non-null   object
#  1   Text    8187 non-null   object
# dtypes: object(2)
# memory usage: 128.0+ KB

# %%
df_clean.dropna()
# Out:
#               UserId                                               Text
# 0     A3SGXH7AUHU8GW  I have bought several of the Vitality canned d...
# 1     A1D87F6ZCVE5NK  Product arrived labeled as Jumbo Salted Peanut...
# 2      ABXLMWJIXXAIN  This is a confection that has been around a fe...
# 3     A395BORC6FGVXV  If you are looking for the secret ingredient i...
# 4     A1UQRSCLF8GW1T  Great taffy at a great price.  There was a wid...
# ...              ...                                                ...
# 8182  A2X1VX3BI2MLZL  I grew up in upstate NY where this stuff was b...
# 8183  A3MEWWXP9I5Q9U  I love this stuff.  My dad brought some home f...
# 8184   A1WQ14J1BP5RY  I love chipotle. Back here in MA when I live n...
# 8185   AGFEBA922M3IF  This energy drink has worked for me. I drink o...
# 8186  A2WH963HKOROMT                                                Our
#
# [8187 rows x 2 columns]

# %%
df_specific_1 = df[df['UserId'] == 'A3PJZ8TU8FDQ1K']

# %%
df_clean['UserId'].value_counts()
# Out:
# UserId
# A1Z54EM24Y40LL    16
# A3PJZ8TU8FDQ1K     7
# A3OXHLG6DIBRW8     7
# A3NHUQ33CFH3VM     7
# AY12DBB0U420B      6
#                   ..
# A10317LUD1C1VJ     1
# A39EW9DLVX70B9     1
# A18SPWHKMN5P86     1
# A2TFLD78C0GRV2     1
# A2WH963HKOROMT     1
# Name: count, Length: 7768, dtype: int64

# %%
df_specific_1.to_csv('specific_user.csv')

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def final_clean(text):
  clean_text = re.compile('https?://\S+|www\.\S+|<.*?>|[^a-zA-Z\s]|\d+')
  final_text = re.sub(clean_text,'',text)
  return final_text

# %%
def TSL(text):
  T = word_tokenize(text)
  stop_words = set(stopwords.words('english'))
  filtered = []
  for w in T:
    if w not in stop_words:
      filtered.append(w)
  lemma = WordNetLemmatizer()
  for i in range(len(filtered)):
    filtered[i] = lemma.lemmatize(filtered[i])
  new_text = ' '.join(filtered)
  return new_text

# %%
df1 = pd.read_csv('/content/drive/MyDrive/specific_user.csv')

# %%
df1['Text'] = df1['Text'].apply(final_clean)
df1['Text'] = df1['Text'].apply(TSL)

# %%
df1.apply(lambda x: x.lower())
# Out:
# 0     if looking less messy version licorice child s...
# 1     i may dating bit i remember first soft batch c...
# 2     try first seafood soup stew theyre amazing the...
# 3     i honestly say i saw difference whatsoever var...
# 4     i think lives better job variety friskies or i...
# 5     this version ground not current cat favorite v...
# 6     according cat stuff great he lick hour eating ...
# 7     i havent cat yet liked one its little interest...
# 8     this cat favorite one he lick bowl clean whene...
# 9     once twice year little variety thats enough ca...
# 10    i honestly say i wont buy variety it look bad ...
# 11    this food variety ground thus cat doesnt care ...
# 12    this cat third favorite food its great stuff g...
# 13    this another favorite house my cat doesnt want...
# 14    this one great basic food whatever cat really ...
# 15    these guy quite high nutritional scale marinat...
# Name: Text, dtype: object

# %%
model = joblib.load('/content/drive/MyDrive/Logistic_Regression_Model.pkl')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
VecT = TfidfVectorizer(max_features=5000)
vectorizer.fit_transform(df1)
X_test = vectorizer.transform(df1)
y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-be4e1c55b83f> in <cell line: 5>()
#       3 vectorizer.fit_transform(df1)
#       4 X_test = vectorizer.transform(df1)
# ----> 5 y_pred = model.predict(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     372         """
#     373         xp, _ = get_namespace(X)
# --> 374         scores = self.decision_function(X)
#     375         if len(scores.shape) == 1:
#     376             indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     349         xp, _ = get_namespace(X)
#     350
# --> 351         X = validate_data(self, X, accept_sparse="csr", reset=False)
#     352         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
# ...

# %%
X_train = pd.read_csv('/content/drive/MyDrive/X_train.csv')

# %%
X_train = X_train['text']

# %%
vectorizer = joblib.load('/content/drive/MyDrive/VecT.pkl')
X_test = vectorizer.transform(df1)
y_pred = model.predict(X_test)

# %%
df_final = pd.DataFrame({'Text':df1,'Prediction':y_pred})

# %%
df_final
# Out:
#                                                  Text  Prediction
# 0   If looking less messy version licorice child s...           1
# 1   I may dating bit I remember first Soft Batch c...           1
# 2   Try first seafood soup stew Theyre amazing The...           1
# 3   I honestly say I saw difference whatsoever var...           1
# 4   I think Lives better job variety Friskies Or I...           1
# 5   This version ground NOt current cat favorite v...           1
# 6   According cat stuff great He lick hour eating ...           1
# 7   I havent cat yet liked one Its little interest...           1
# 8   This cat favorite one He lick bowl clean whene...           1
# 9   Once twice year little variety thats enough ca...           1
# 10  I honestly say I wont buy variety It look bad ...           0
# 11  This food variety ground thus cat doesnt care ...           1
# 12  This cat third favorite food Its great stuff g...           0
# ...

# %%
df_final['Prediction'].value_counts()
# Out:
# Prediction
# 1    13
# 0     3
# Name: count, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-ab64e7d4d42b> in <cell line: 1>()
# ----> 1 prediction['count']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# ...

# %%
def final_code(text): # Changed input to text instead of df
  text = final_clean(text) # Applying final_clean directly to the text
  text = TSL(text)       # Applying TSL directly to the text
  text = text.lower()    # Applying lower directly to the text
  X_test = vectorizer.transform([text]) # Transforming the processed text
  y_pred = model.predict(X_test)
  # Creating a DataFrame for the single prediction
  new_df = pd.DataFrame({'Text':[text],'Prediction':y_pred})
  return new_df.iloc[0]['Prediction']

# %%
df_specific_2 = df[df['UserId'] == 'A3PJZ8TU8FDQ1K']

# %%
df_specific_2.head()
# Out:
#       Id   ProductId          UserId   ProfileName  HelpfulnessNumerator  \
# 466  467  B000G6RYNE  A3PJZ8TU8FDQ1K  Jared Castle                     0
# 467  468  B000G6RYNE  A3PJZ8TU8FDQ1K  Jared Castle                     0
# 574  575  B000G6RYNE  A3PJZ8TU8FDQ1K  Jared Castle                     2
# 602  603  B000G6RYNE  A3PJZ8TU8FDQ1K  Jared Castle                     1
# 603  604  B000G6RYNE  A3PJZ8TU8FDQ1K  Jared Castle                     1
#
#      HelpfulnessDenominator  Score        Time  \
# 466                       0      5  1231718400
# 467                       0      5  1231718400
# 574                       2      5  1231718400
# 602                       1      5  1237075200
# 603                       1      5  1229385600
#
#                                                Summary  \
# 466        One bite and you'll become a "chippoisseur"
# 467  Crunchy, salty, sweet...finally, a Superbowl s...
# 574        One bite and you'll become a "chippoisseur"
# ...

# %%
df_specific_2 = df_specific_2['Text']

# %%
prediction = df_specific_2.apply(final_code)
df_final = pd.DataFrame({'Text':df_specific_2,'Prediction':prediction})

# %%
df_final
# Out:
#                                                    Text  Prediction
# 466   I'm addicted to salty and tangy flavors, so wh...           1
# 467   These Honey Dijon chips bring a terrific balan...           1
# 574   I'm addicted to salty and tangy flavors, so wh...           1
# 602   As an Oregonian, I make a point of sharing the...           1
# 603   I'm addicted to salty and tangy flavors, so wh...           1
# 6797  As part of Amazon's Vine Program I received tw...           0
# 7988  Behind the 12 packets of Via instant coffee, S...           0
