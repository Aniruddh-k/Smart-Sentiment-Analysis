# %%
import pandas as pd
import joblib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df =  pd.read_csv('/content/drive/MyDrive/Train.csv/cleaned_reviews.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                               text  label
# 0           0  grew b watching loving thunderbird mate school...      0
# 1           1  put movie dvd player sat coke chip expectation...      0
# 2           2  people know particular time past like feel nee...      0
# 3           3  even though great interest biblical movie bore...      0
# 4           4  im die hard dad army fan nothing ever change g...      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  40000 non-null  int64
#  1   text        40000 non-null  object
#  2   label       40000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 937.6+ KB

# %%
df.drop('Unnamed: 0',axis =1)
# Out:
#                                                     text  label
# 0      grew b watching loving thunderbird mate school...      0
# 1      put movie dvd player sat coke chip expectation...      0
# 2      people know particular time past like feel nee...      0
# 3      even though great interest biblical movie bore...      0
# 4      im die hard dad army fan nothing ever change g...      1
# ...                                                  ...    ...
# 39995  western union something forgotten classic west...      1
# 39996  movie incredible piece work explores every noo...      1
# 39997  wife watched movie plan visit sicily stromboli...      0
# 39998  first watched flatliners amazed necessary feat...      1
# 39999  would film good gross estimated award nominati...      1
#
# [40000 rows x 2 columns]

# %%
##TF:IDF

# %%
from sklearn.model_selection import train_test_split

# %%
x = df['text']
y = df['label']

X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size = 0.2,random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

VecT = TfidfVectorizer(max_features=5000)
X_train_vec = VecT.fit_transform(X_train)
X_test_vec = VecT.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

clf = LogisticRegression(random_state=42)
clf.fit(X_train_vec,Y_train)
y_pred = clf.predict(X_test_vec)

accuracy_score(Y_test,y_pred)
# Out:
# 0.88475

# %%
joblib.dump(clf,'Logistic_Regression_Model.pkl')
# Out:
# ['Logistic_Regression_Model.pkl']

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88      3966
#            1       0.88      0.89      0.89      4034
#
#     accuracy                           0.88      8000
#    macro avg       0.88      0.88      0.88      8000
# weighted avg       0.88      0.88      0.88      8000

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(Y_test,y_pred)
# Out:
# array([[3470,  496],
#        [ 426, 3608]])

# %%
test_df = pd.DataFrame({'text': X_test.values, 'label': Y_test.values, 'Pred_label': y_pred })

# %%
df['Pred_label'] = ''

# %%
df.loc[X_test.index,'Pred_label'] = y_pred

# %%
test_df.head()
# Out:
#                                                 text  label  Pred_label
# 0  central theme movie seems confusion relationsh...      0           0
# 1  excellent example cowboy noir called unemploye...      1           1
# 2  ending made heart jump throat proceeded leave ...      0           1
# 3  chosen one appreciate quality story character ...      1           1
# 4  really funny film especially second third four...      1           1

# %%
test_df.to_csv('test.csv')

# %%
model = joblib.load('/content/drive/MyDrive/Logistic_Regression_Model.pkl')

# %%
y_pred = model.predict(X_test_vec)

# %%
accuracy_score(Y_test,y_pred)
# Out:
# 0.754375

# %%
df1 = pd.read_csv('/content/drive/MyDrive/test.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0                                               text  label  \
# 0           0  central theme movie seems confusion relationsh...      0
# 1           1  excellent example cowboy noir called unemploye...      1
# 2           2  ending made heart jump throat proceeded leave ...      0
# 3           3  chosen one appreciate quality story character ...      1
# 4           4  really funny film especially second third four...      1
#
#    Pred_label
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1

# %%
X_train.to_csv('X_train.csv')

# %%
joblib.dump(VecT,'VecT.pkl')
# Out:
# ['VecT.pkl']
